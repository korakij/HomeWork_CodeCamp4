# %% [markdown]
# 1 - 5

# %%
print("Merry X'Mas")
print("What's happend?")
print("สวัสดีวันจันทร์")
print('ความแตกต่างระหว่างคนเก่งกับคนไม่เก่ง คือ "การใช้เวลาว่างให้เป็นประโยชน์"')
print('apple, papaya, banana, orange')
# Out:
# Merry X'Mas
# What's happend?
# สวัสดีวันจันทร์
# ความแตกต่างระหว่างคนเก่งกับคนไม่เก่ง คือ "การใช้เวลาว่างให้เป็นประโยชน์"
# apple, papaya, banana, orange

# %% [markdown]
# 6.

# %%
 a = 2
 b = 3
 print(a,'x',b,'=',a*b)
# Out:
# 2 x 3 = 6

# %% [markdown]
# 7.-9.

# %%
import math
print(math.pi)
print("%.6f" % 100)
print(25)
# Out:
# 3.141592653589793
# 100.000000
# 25

# %% [markdown]
# 10 - 17.

# %%
import math

print('a\nan\nant\n')
print('\t*\n*\t*\t*\n\t*\n')
print('*\t+\t*\n\n+\t*\t+\n\n*\t+\t*\n')
print('I want to ask you "Why don\'t you drive to work?"\n')
print(math.pow(2,0) + 0,',',math.pow(2,1) + 1,',',math.pow(2,2) + 2,',',math.pow(2,3) + 3,',',math.pow(2,4) + 4,',',math.pow(2,5) + 5,'\n')
print('"I don\'t have a car"\n')
print('\t/\\/\\/\\\n\t/\\/\\/\\\n\t||||||\n')
# Out:
# a
# an
# ant
#
# 	*
# *	*	*
# 	*
#
# *	+	*
#
# +	*	+
#
# *	+	*
#
# I want to ask you "Why don't you drive to work?"
#
# 1.0 , 3.0 , 6.0 , 11.0 , 20.0 , 37.0
#
# "I don't have a car"
#
# 	/\/\/\
# 	/\/\/\
# 	||||||

# %% [markdown]
# 18.-23.

# %%
a,b = 2,3
print(a,'+',b,'=',b,'+',a,'=',a+b,'\n')

a,b,c = 2,3,5
print(a,'*','(',b,'+',c,')=',a,'*',b,'+',a,'*',c,'=',a*b,'+',a*c,'=',a*b+a*c,'\n')

a,b = 72,80
print('เดือนที่แล้วฉันหัก ',a,' เดือนนี้ฉันหนัก ',b,'\n')

print('How many hours do you exercise?\n')

print("About / Around two hours\n")
# Out:
# 2 + 3 = 3 + 2 = 5
#
# 2 * ( 3 + 5 )= 2 * 3 + 2 * 5 = 6 + 10 = 16
#
# เดือนที่แล้วฉันหัก  72  เดือนนี้ฉันหนัก  80
#
# How many hours do you exercise?
#
# About / Around two hours

# %% [markdown]
# 23.-30.

# %%
a,b = 2.4,2.5
print(a,'+',b,'=',"%.4f" %(a + b),'\n')

print('\\\t\t/\n\tX\t\n/\t\t\\\n')

print('Just because something\nthinks differently from you,\ndoes that mean it\'s not thinking?\n')

profit = 10000
print('เมื่อวานฉันได้กำไร ',profit,'บาท\n')

a,b = 5,100
print(a,' เท่าของ ',b,'มีค่าเท่ากับ ',a*b)

print('You get a new job?!That\'s so exciting!\n')

heaven = 6
print('สวรรค์มี ',heaven,' ชั้้น\n')

a=3.5
print('เขามีเงินเยอะกว่าฉัน ',a)
# Out:
# 2.4 + 2.5 = 4.9000
#
# \		/
# 	X
# /		\
#
# Just because something
# thinks differently from you,
# does that mean it's not thinking?
#
# เมื่อวานฉันได้กำไร  10000 บาท
#
# 5  เท่าของ  100 มีค่าเท่ากับ  500
# You get a new job?!That's so exciting!
#
# สวรรค์มี  6  ชั้้น
#
# เขามีเงินเยอะกว่าฉัน  3.5
